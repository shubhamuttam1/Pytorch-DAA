# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import save_image
import torchvision.models as models
import time
import os
import uuid
from itertools import chain
import torchvision
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np
import sys
import time
from scipy.spatial.distance import pdist, squareform, cdist
import torch.backends.cudnn as cudnn
import json
import sys
import math

# %%
cudan = 1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.autograd import Variable


def conv3x3(in_planes, out_planes, stride=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = conv3x3(in_planes, planes, stride)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = conv3x3(planes, planes)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class PreActBlock(nn.Module):
    '''Pre-activation version of the BasicBlock.'''
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(PreActBlock, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.conv1 = conv3x3(in_planes, planes, stride)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv2 = conv3x3(planes, planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False)
            )

    def forward(self, x):
        out = F.relu(self.bn1(x))
        shortcut = self.shortcut(out)
        out = self.conv1(out)
        out = self.conv2(F.relu(self.bn2(out)))
        out += shortcut
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class PreActBottleneck(nn.Module):
    '''Pre-activation version of the original Bottleneck module.'''
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(PreActBottleneck, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn3 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False)
            )

    def forward(self, x):
        out = F.relu(self.bn1(x))
        shortcut = self.shortcut(out)
        out = self.conv1(out)
        out = self.conv2(F.relu(self.bn2(out)))
        out = self.conv3(F.relu(self.bn3(out)))
        out += shortcut
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = conv3x3(3,64)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x, lin=0, lout=5):
        out = x
        if lin < 1 and lout > -1:
            out = self.conv1(out)
            out = self.bn1(out)
            out = F.relu(out)
        if lin < 2 and lout > 0:
            out = self.layer1(out)
        if lin < 3 and lout > 1:
            out = self.layer2(out)
        if lin < 4 and lout > 2:
            out = self.layer3(out)
        if lin < 5 and lout > 3:
            out = self.layer4(out)
        if lout > 4:
            out = F.avg_pool2d(out, 4)
            out = out.view(out.size(0), -1)
            out = self.linear(out)
        return out


def ResNet18():
    return ResNet(PreActBlock, [2,2,2,2])

def ResNet34():
    return ResNet(BasicBlock, [3,4,6,3])

def ResNet50():
    return ResNet(Bottleneck, [3,4,6,3])

def ResNet101():
    return ResNet(Bottleneck, [3,4,23,3])

def ResNet152():
    return ResNet(Bottleneck, [3,8,36,3])

# %%
net = ResNet18()
net.cuda()
net = torch.nn.DataParallel(net)
print(torch.cuda.device_count())
cudnn.benchmark = True
print('Using CUDA..')
net.load_state_dict(torch.load("./norm05_IATresnet18_epo_190"))
# Out:
# 1
# Using CUDA..
# <All keys matched successfully>

# %%
device = torch.device("cuda")
net.eval()
# Out:
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (layer1): Sequential(
#       (0): PreActBlock(
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (shortcut): Sequential()
#       )
#       (1): PreActBlock(
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (shortcut): Sequential()
#       )
#     )
#     (layer2): Sequential(
#       (0): PreActBlock(
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (shortcut): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         )
#       )
#       (1): PreActBlock(
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (shortcut): Sequential()
#       )
#     )
#     (layer3): Sequential(
#       (0): PreActBlock(
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (shortcut): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         )
#       )
#       (1): PreActBlock(
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (shortcut): Sequential()
#       )
#     )
#     (layer4): Sequential(
#       (0): PreActBlock(
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (shortcut): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         )
#       )
#       (1): PreActBlock(
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (shortcut): Sequential()
#       )
#     )
#     (linear): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
c = -0.001

# %%
class LinfPGDAttack:
    def __init__(self, model, epsilon, k, a, random_start, loss_func):
        """Attack parameter initialization. The attack performs k steps of
           size a, while always staying within epsilon from the initial
           point."""
        self.model = model
        self.epsilon = epsilon#/255.0
        self.k = k
        self.a = a
        self.rand = random_start
        self.loss_func = loss_func
        self.step_size = 0.01
        if loss_func == 'xent':
              self.loss_fun =  torch.nn.CrossEntropyLoss()
        self.grad = None
    
    def find_grad(self,input_image, input_label):
        input_image = torch.autograd.Variable(torch.tensor(input_image))
        input_image.requires_grad= True
        input_label = torch.tensor(input_label).to(device,dtype=torch.int64)
        prediction = self.model(input_image.to(device,dtype=torch.float))
        loss_value = self.loss_fun( prediction,input_label)
        gradient = torch.autograd.grad(loss_value, input_image)
        return np.array(gradient[0])

    def perturb(self, x_nat, x_adv, y):

        batch_size = x_nat.shape[0]  
        for epoch in range(10):
            grad = self.find_grad(x_adv, y)
            kxy, dxkxy = self.svgd_kernel(x_adv)
            svgd = -(np.matmul(kxy, -np.array(grad).reshape([-1, 32*32*3])).reshape([-1, 3, 32, 32]) + dxkxy)/batch_size
            x_adv = np.add(x_adv, self.step_size * np.sign(c*svgd + grad), out=x_adv, casting='unsafe')
            x_adv = np.clip(x_adv, x_nat - self.epsilon, x_nat + self.epsilon) 
            x_adv = np.clip(x_adv, min_clip, max_clip)
        return x_adv

    def svgd_kernel(self, Theta):
        theta = Theta.reshape([-1, 32*32*3])

        sq_dist = pdist(theta)
        pairwise_dists = squareform(sq_dist)**2

        h = np.median(pairwise_dists)
        h = np.sqrt(0.5*h/np.log(theta.shape[0]))
        Kxy = np.exp(-pairwise_dists / h**2 / 2)

        dxkxy = -np.matmul(Kxy, theta)
        sumkxy = np.sum(Kxy, axis=1)

        for i in range(theta.shape[1]):
            dxkxy[:, i] = dxkxy[:,i] + np.multiply(theta[:,i],sumkxy)
        dxkxy = dxkxy / (h**2)

        dxkxy = np.reshape(dxkxy, [-1, 3, 32, 32])
        return (Kxy, dxkxy)

    def wgf_kernel(self, theta):
        sq_dist = pdist(theta)
        pairwise_dists = squareform(sq_dist)**2

        h = np.median(pairwise_dists)  
        h = np.sqrt(0.5 * h / np.log(theta.shape[0] + 1))

        Kxy = np.exp( -pairwise_dists / h**2 / 2)
        Kxy = np.multiply((pairwise_dists / h**2 / 2 - 1), Kxy)

        dxkxy = -np.matmul(Kxy, theta)
        sumkxy = np.sum(Kxy, axis=1)
        for i in range(theta.shape[1]):
            dxkxy[:, i] = dxkxy[:,i] + np.multiply(theta[:,i],sumkxy)

        return (Kxy, dxkxy)

# %%
BATCH_SIZE = 128

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

train_dataset = datasets.CIFAR10(root='../data', 
                               train=True, 
                               transform=transform_test,
                               download=True)

test_dataset = datasets.CIFAR10(root='../data', 
                              train=False, 
                              transform=transform_test)


train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=BATCH_SIZE, 
                          shuffle=True)

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=BATCH_SIZE, 
                         shuffle=False)
# Out:
# Files already downloaded and verified

# %%
new_test_data = []
for x,y in test_dataset:
    new_test_data.append(x.view(-1,3,32,32))

# %%
new_test_data = torch.cat(new_test_data, dim=0)

# %%
max_clip = torch.max(new_test_data).item()
min_clip = torch.min(new_test_data).item()

# %%
def make_categorical(arr,num_class):
    cat_arr = np.zeros((len(arr),num_class))
    for k in range(len(arr)):
        cat_arr[k][arr[k]] = 1
    return(cat_arr)

# %%
test_data = np.array(new_test_data.data)
test_tar = np.array(test_dataset.targets)
print(test_tar.shape)
test_lab_categorical = make_categorical(np.array(test_dataset.targets),10)
# Out:
# (10000,)

# %%
attack = LinfPGDAttack(net,
                         0.20,
                         100,
                         0.01,
                         True,
                         "xent")
x_adv_final = np.copy(test_data)
y_adv_final = np.copy(test_tar)
num_eval_examples = len(test_data)
eval_batch_size = 64
num_batches = int(len(test_data)/eval_batch_size)

# %%
for restart in range(10):
    succ = 0
    permutation = np.arange(num_eval_examples)
    idx = np.arange(num_eval_examples)
    print("min",torch.min(torch.tensor(test_data)))
    print("max",torch.max(torch.tensor(test_data)))
    x_test, y_test = np.copy(test_data), np.copy(test_tar)
    x_adv = x_test + np.random.uniform(-attack.epsilon, attack.epsilon, x_test.shape)
    print("min",torch.min(torch.tensor(x_adv)))
    print("max",torch.max(torch.tensor(x_adv)))


    t0 = time.time()
    x_test_temp, x_adv_temp, y_test_temp = np.copy(test_data), np.copy(x_adv), np.copy(test_tar)
    for epoch in range(int(attack.k/10)):

        np.random.shuffle(idx)
        x_test_temp, x_adv_temp, y_test_temp = x_test_temp[idx], x_adv_temp[idx], y_test_temp[idx]

        permutation = permutation[idx]

        for ibatch in range(num_batches):
            print("====> restart : {}\{} ====> epoch : {}\{} ====> ibatch : {}\{}".format(restart,10,epoch,int(attack.k/10),ibatch,num_batches))
            sys.stdout.flush()
            bstart = ibatch * eval_batch_size
            bend = min(bstart + eval_batch_size, num_eval_examples)

            x_batch = x_test_temp[bstart:bend, :]
            x_batch_adv = x_adv_temp[bstart:bend, :]
            y_batch = y_test_temp[bstart:bend]


            x_adv_temp[bstart:bend, :] = attack.perturb(x_batch, x_batch_adv, y_batch)

    inv_permutation = np.argsort(permutation)
    x_adv = x_adv_temp[inv_permutation]
    print("x_adv.shape",x_adv.shape)
    print("test_data.shape",test_data.shape)
    print('round Linf: ', np.max(np.abs(x_adv - test_data)))

    sys.stdout.flush()

    for ibatch in range(num_batches):
        bstart = ibatch * eval_batch_size
        bend = min(bstart + eval_batch_size, num_eval_examples)

        x_batch_adv = x_adv[bstart:bend, :]
        y_batch = y_test[bstart:bend]

        y_pred = attack.model(torch.tensor(x_batch_adv).to(device,dtype=torch.float))#,training=False)

        y_pred = np.argmax(y_pred.detach().cpu().numpy(), 1)



        correct_prediction = np.equal(y_pred, y_batch)

        for i in range(correct_prediction.shape[0]):
            if not correct_prediction[i]:
                succ+=1
                x_adv_final[bstart+i] = x_batch_adv[i] 
                y_adv_final[bstart+i] = y_batch[i] 
                
    print("Success : ",succ)
    print("Time for repeat: {}".format((time.time()-t0)/60))
    sys.stdout.flush()
# Out:
# min tensor(-1.)
# max tensor(1.)
# min tensor(-1.2000, dtype=torch.float64)
# max tensor(1.2000, dtype=torch.float64)
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 0\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 1\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 2\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 3\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 4\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 5\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 6\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 7\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 8\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 9\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 10\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 11\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 12\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 13\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 14\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 15\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 16\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 17\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 18\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 19\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 20\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 21\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 22\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 23\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 24\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 25\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 26\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 27\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 28\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 29\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 30\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 31\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 32\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 33\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 34\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 35\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 36\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 37\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 38\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 39\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 40\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 41\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 42\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 43\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 44\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 45\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 46\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 47\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 48\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 49\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 50\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 51\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 52\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 53\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 54\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 55\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 56\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 57\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 58\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 59\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 60\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 61\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 62\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 63\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 64\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 65\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 66\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 67\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 68\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 69\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 70\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 71\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 72\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 73\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 74\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 75\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 76\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 77\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 78\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 79\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 80\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 81\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 82\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 83\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 84\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 85\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 86\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 87\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 88\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 89\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 90\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 91\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 92\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 93\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 94\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 95\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 96\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 97\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 98\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 99\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 100\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 101\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 102\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 103\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 104\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 105\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 106\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 107\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 108\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 109\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 110\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 111\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 112\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 113\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 114\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 115\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 116\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 117\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 118\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 119\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 120\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 121\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 122\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 123\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 124\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 125\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 126\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 127\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 128\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 129\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 130\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 131\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 132\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 133\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 134\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 135\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 136\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 137\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 138\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 139\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 140\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 141\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 142\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 143\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 144\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 145\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 146\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 147\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 148\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 149\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 150\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 151\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 152\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 153\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 154\156
# ====> restart : 0\10 ====> epoch : 0\10 ====> ibatch : 155\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 0\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 1\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 2\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 3\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 4\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 5\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 6\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 7\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 8\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 9\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 10\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 11\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 12\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 13\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 14\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 15\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 16\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 17\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 18\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 19\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 20\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 21\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 22\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 23\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 24\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 25\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 26\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 27\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 28\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 29\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 30\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 31\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 32\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 33\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 34\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 35\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 36\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 37\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 38\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 39\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 40\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 41\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 42\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 43\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 44\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 45\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 46\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 47\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 48\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 49\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 50\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 51\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 52\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 53\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 54\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 55\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 56\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 57\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 58\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 59\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 60\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 61\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 62\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 63\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 64\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 65\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 66\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 67\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 68\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 69\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 70\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 71\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 72\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 73\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 74\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 75\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 76\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 77\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 78\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 79\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 80\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 81\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 82\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 83\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 84\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 85\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 86\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 87\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 88\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 89\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 90\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 91\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 92\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 93\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 94\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 95\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 96\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 97\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 98\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 99\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 100\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 101\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 102\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 103\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 104\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 105\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 106\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 107\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 108\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 109\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 110\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 111\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 112\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 113\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 114\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 115\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 116\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 117\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 118\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 119\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 120\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 121\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 122\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 123\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 124\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 125\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 126\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 127\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 128\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 129\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 130\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 131\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 132\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 133\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 134\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 135\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 136\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 137\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 138\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 139\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 140\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 141\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 142\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 143\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 144\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 145\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 146\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 147\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 148\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 149\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 150\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 151\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 152\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 153\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 154\156
# ====> restart : 0\10 ====> epoch : 1\10 ====> ibatch : 155\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 0\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 1\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 2\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 3\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 4\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 5\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 6\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 7\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 8\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 9\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 10\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 11\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 12\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 13\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 14\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 15\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 16\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 17\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 18\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 19\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 20\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 21\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 22\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 23\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 24\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 25\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 26\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 27\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 28\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 29\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 30\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 31\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 32\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 33\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 34\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 35\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 36\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 37\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 38\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 39\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 40\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 41\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 42\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 43\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 44\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 45\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 46\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 47\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 48\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 49\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 50\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 51\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 52\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 53\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 54\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 55\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 56\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 57\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 58\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 59\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 60\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 61\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 62\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 63\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 64\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 65\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 66\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 67\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 68\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 69\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 70\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 71\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 72\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 73\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 74\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 75\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 76\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 77\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 78\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 79\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 80\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 81\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 82\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 83\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 84\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 85\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 86\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 87\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 88\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 89\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 90\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 91\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 92\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 93\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 94\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 95\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 96\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 97\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 98\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 99\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 100\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 101\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 102\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 103\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 104\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 105\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 106\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 107\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 108\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 109\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 110\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 111\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 112\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 113\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 114\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 115\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 116\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 117\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 118\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 119\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 120\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 121\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 122\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 123\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 124\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 125\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 126\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 127\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 128\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 129\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 130\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 131\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 132\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 133\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 134\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 135\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 136\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 137\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 138\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 139\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 140\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 141\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 142\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 143\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 144\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 145\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 146\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 147\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 148\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 149\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 150\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 151\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 152\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 153\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 154\156
# ====> restart : 0\10 ====> epoch : 2\10 ====> ibatch : 155\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 0\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 1\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 2\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 3\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 4\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 5\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 6\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 7\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 8\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 9\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 10\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 11\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 12\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 13\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 14\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 15\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 16\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 17\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 18\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 19\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 20\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 21\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 22\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 23\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 24\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 25\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 26\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 27\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 28\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 29\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 30\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 31\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 32\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 33\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 34\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 35\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 36\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 37\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 38\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 39\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 40\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 41\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 42\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 43\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 44\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 45\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 46\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 47\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 48\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 49\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 50\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 51\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 52\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 53\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 54\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 55\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 56\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 57\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 58\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 59\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 60\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 61\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 62\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 63\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 64\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 65\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 66\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 67\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 68\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 69\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 70\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 71\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 72\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 73\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 74\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 75\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 76\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 77\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 78\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 79\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 80\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 81\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 82\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 83\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 84\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 85\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 86\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 87\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 88\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 89\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 90\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 91\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 92\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 93\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 94\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 95\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 96\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 97\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 98\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 99\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 100\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 101\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 102\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 103\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 104\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 105\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 106\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 107\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 108\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 109\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 110\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 111\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 112\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 113\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 114\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 115\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 116\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 117\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 118\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 119\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 120\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 121\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 122\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 123\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 124\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 125\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 126\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 127\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 128\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 129\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 130\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 131\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 132\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 133\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 134\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 135\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 136\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 137\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 138\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 139\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 140\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 141\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 142\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 143\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 144\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 145\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 146\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 147\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 148\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 149\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 150\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 151\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 152\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 153\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 154\156
# ====> restart : 0\10 ====> epoch : 3\10 ====> ibatch : 155\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 0\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 1\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 2\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 3\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 4\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 5\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 6\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 7\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 8\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 9\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 10\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 11\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 12\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 13\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 14\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 15\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 16\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 17\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 18\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 19\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 20\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 21\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 22\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 23\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 24\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 25\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 26\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 27\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 28\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 29\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 30\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 31\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 32\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 33\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 34\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 35\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 36\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 37\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 38\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 39\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 40\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 41\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 42\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 43\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 44\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 45\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 46\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 47\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 48\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 49\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 50\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 51\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 52\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 53\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 54\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 55\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 56\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 57\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 58\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 59\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 60\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 61\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 62\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 63\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 64\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 65\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 66\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 67\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 68\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 69\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 70\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 71\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 72\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 73\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 74\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 75\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 76\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 77\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 78\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 79\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 80\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 81\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 82\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 83\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 84\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 85\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 86\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 87\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 88\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 89\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 90\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 91\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 92\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 93\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 94\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 95\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 96\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 97\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 98\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 99\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 100\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 101\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 102\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 103\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 104\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 105\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 106\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 107\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 108\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 109\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 110\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 111\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 112\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 113\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 114\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 115\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 116\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 117\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 118\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 119\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 120\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 121\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 122\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 123\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 124\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 125\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 126\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 127\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 128\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 129\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 130\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 131\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 132\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 133\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 134\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 135\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 136\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 137\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 138\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 139\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 140\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 141\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 142\156
# ====> restart : 0\10 ====> epoch : 4\10 ====> ibatch : 143\156
# ...
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 59\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 60\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 61\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 62\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 63\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 64\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 65\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 66\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 67\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 68\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 69\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 70\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 71\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 72\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 73\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 74\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 75\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 76\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 77\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 78\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 79\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 80\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 81\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 82\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 83\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 84\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 85\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 86\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 87\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 88\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 89\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 90\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 91\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 92\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 93\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 94\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 95\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 96\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 97\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 98\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 99\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 100\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 101\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 102\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 103\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 104\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 105\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 106\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 107\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 108\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 109\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 110\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 111\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 112\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 113\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 114\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 115\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 116\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 117\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 118\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 119\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 120\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 121\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 122\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 123\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 124\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 125\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 126\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 127\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 128\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 129\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 130\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 131\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 132\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 133\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 134\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 135\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 136\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 137\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 138\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 139\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 140\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 141\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 142\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 143\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 144\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 145\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 146\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 147\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 148\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 149\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 150\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 151\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 152\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 153\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 154\156
# ====> restart : 9\10 ====> epoch : 8\10 ====> ibatch : 155\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 0\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 1\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 2\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 3\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 4\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 5\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 6\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 7\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 8\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 9\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 10\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 11\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 12\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 13\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 14\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 15\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 16\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 17\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 18\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 19\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 20\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 21\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 22\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 23\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 24\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 25\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 26\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 27\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 28\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 29\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 30\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 31\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 32\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 33\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 34\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 35\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 36\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 37\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 38\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 39\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 40\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 41\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 42\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 43\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 44\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 45\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 46\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 47\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 48\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 49\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 50\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 51\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 52\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 53\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 54\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 55\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 56\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 57\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 58\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 59\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 60\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 61\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 62\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 63\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 64\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 65\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 66\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 67\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 68\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 69\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 70\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 71\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 72\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 73\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 74\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 75\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 76\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 77\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 78\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 79\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 80\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 81\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 82\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 83\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 84\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 85\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 86\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 87\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 88\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 89\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 90\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 91\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 92\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 93\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 94\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 95\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 96\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 97\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 98\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 99\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 100\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 101\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 102\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 103\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 104\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 105\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 106\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 107\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 108\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 109\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 110\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 111\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 112\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 113\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 114\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 115\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 116\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 117\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 118\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 119\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 120\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 121\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 122\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 123\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 124\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 125\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 126\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 127\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 128\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 129\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 130\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 131\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 132\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 133\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 134\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 135\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 136\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 137\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 138\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 139\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 140\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 141\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 142\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 143\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 144\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 145\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 146\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 147\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 148\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 149\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 150\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 151\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 152\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 153\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 154\156
# ====> restart : 9\10 ====> epoch : 9\10 ====> ibatch : 155\156
# x_adv.shape (10000, 3, 32, 32)
# test_data.shape (10000, 3, 32, 32)
# round Linf:  0.20000000298023224
# Success :  9837
# Time for repeat: 18.221392655372618

# %%
np.save("DAA_adv_blob_test_IAT_norm_100",np.array(x_adv_final ))
np.save("DAA_adv_blob_target_IAT_norm_100",np.array(y_adv_final ))
print("adv images saved")
sys.stdout.flush()
# Out:
# adv images saved
